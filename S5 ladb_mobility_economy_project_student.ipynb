# %% [markdown]
# # ¡Hola Leidy! 😊
#
# Mi nombre es **Alejandro Castellanos** y hoy tengo el placer de ser el revisor de tu proyecto.
#
# Voy a revisar todo tu código con detalle, buscando tanto los puntos fuertes como aquellos en los que podrías mejorar. Te dejaré comentarios a lo largo del notebook, destacando lo que has hecho bien y sugiriendo ajustes donde sea necesario. Si encuentro algún error, no te preocupes, te lo haré saber de forma clara y te daré información útil para que puedas corregirlo en la próxima iteración. Si en algún punto tienes comentarios, siéntete libre de dejarlos también.
#
#
# Encontrarás mis comentarios específicos dentro de cajas verdes, amarillas o rojas, es muy importante que no muevas, modifiques o borres mis comentarios, con el fin de tener un seguimiento adecuado de tu proceso:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>
#
# A continuación te dejaré un comentario general con mi valoración del proyecto. **¡Mi objetivo es que sigas aprendiendo y mejorando con cada paso!**

# %% [markdown]
# ----

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario General del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Leidy, lograste construir una base ordenada para el análisis al cargar correctamente los datos, revisar su estructura y plantear una agregación coherente, lo que muestra un buen entendimiento del flujo inicial de trabajo con datos
#
# Sin embargo, es importante que corrijas varios puntos clave para que el proceso sea consistente y confiable, hay problemas en la estandarización de nombres entre datasets que afectan directamente el merge, conversiones de tipos incompletas (especialmente variables numéricas y fechas) que pueden generar errores en el análisis, y el uso de columnas incorrectas para definir el periodo de estudio, lo cual impacta la validez de los resultados; además, el merge final no está bien aplicado ni validado, los gráficos presentan inconsistencias tanto en ejecución como en interpretación, y falta desarrollar el análisis final para comunicar hallazgos de manera clara, lo cual es esencial en proyectos de datos.
#
#
# No debes desanimarte, esto hace parte del proceso de aprendizaje y hasta el momento has demostrado un gran dominio en la manejo y análisis de datos, por lo que estoy seguro que podrás hacer los ajustes fácilmente.
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario General del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# ¡Leidy excelente trabajo con los ajustes! Tu proyecto ahora cumple con todos los objetivos propuestos. Estoy seguro de que lo que aprendiste aquí te será muy útil más adelante.
#
# ¡Éxito en tu próximo sprint! 🚀
#
# *Estado del Proyecto:* **Aprobado**
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# ## Introducción
#
# Como analista de datos, tu objetivo es **evaluar cómo la movilidad urbana se relaciona con la productividad económica en las principales ciudades latinoamericanas**.
# Para ello trabajarás con datos reales de TomTom Traffic Index y OECD Cities, que deberás limpiar, combinar y analizar para identificar en qué ciudades conviene invertir en infraestructura de transporte.

# %% [markdown]
# ## 🧩 Paso 1: Cargar y explorar
#
# Antes de limpiar o combinar los datos, es necesario **familiarizarte con la estructura de ambos datasets**.
# En esta etapa, validarás que los archivos se carguen correctamente, conocerás sus columnas y tipos de datos, y detectarás posibles inconsistencias.
#
# ### 1.1 Carga de datos y vista rápida
#
# **🎯Objetivo:**
# Importar las librerías necesarias, cargar los archivos CSV en DataFrames y realizar una revisión preliminar para entender su contenido.
#
# **Instrucciones:**
# - Importa las librerías `pandas`, `numpy`, `seaborn` y `matplotlib.pyplot`.
# - Carga los archivos usando `pd.read_csv()`:
#   - `'/datasets/tomtom_traffic.csv'`
#   - `/datasets/oecd_city_economy.csv` `.
# - Guarda los DataFrames en las variables `traffic` y `eco`.
# - Muestra las primeras 5 filas de cada DataFrame.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt # importar librerías

# %%
# cargar archivos
traffic = pd.read_csv('/datasets/tomtom_traffic.csv')
eco = pd.read_csv('/datasets/oecd_city_economy.csv') #completa el código

# %%
traffic.head(5)
# mostrar las primeras 5 filas de traffic
# Out:
#   Country       City            UpdateTimeUTC  JamsDelay  TrafficIndexLive  \
# 0     ARE  abu-dhabi  2025-01-13 04:01:30.001      650.7              36.0
# 1     ARE  abu-dhabi  2025-01-13 03:46:00.000      540.4              30.0
# 2     ARE  abu-dhabi  2025-01-13 02:46:30.000       71.8               7.0
# 3     ARE  abu-dhabi  2025-01-13 01:46:30.001        8.2               2.0
# 4     ARE  abu-dhabi  2025-01-13 00:01:30.000        1.1               1.0
#
#    JamsLengthInKms  JamsCount  TrafficIndexWeekAgo     UpdateTimeUTCWeekAgo  \
# 0            109.1      162.0                 30.0  2025-01-06 04:01:30.000
# 1            101.4      136.0                 27.0  2025-01-06 03:46:30.001
# 2             18.9       23.0                  6.0  2025-01-06 02:46:30.000
# 3              4.1        2.0                  2.0  2025-01-06 01:46:30.000
# 4              0.2        1.0                  1.0  2025-01-06 00:01:30.000
#
#    TravelTimeLivePer10KmsMins  TravelTimeHistoricPer10KmsMins  MinsDelay
# 0                   11.614767                       10.265330   1.349437
# 1                   11.003180                       10.031544   0.971635
# 2                    8.196278                        8.196510  -0.000232
# 3                    7.723808                        7.899046  -0.175238
# 4                    8.336363                        8.604379  -0.268016

# %%
eco.head(5) # mostrar las primeras 5 filas de eco
# Out:
#    Year            City    Country City GDP/capita Unemployment %  \
# 0  2023    buenos-aires  Argentina       15.782,00           6.2%
# 1  2023       sao-paulo     Brazil       14.475,00           9.1%
# 2  2023  rio-de-janeiro     Brazil       13.142,00           9.8%
# 3  2023        brasilia     Brazil       15.999,00           8.3%
# 4  2023        salvador     Brazil        8.761,00          13.1%
#
#   PM2.5 (μg/m³) Population (M)
# 0          15,2          15,30
# 1         29,50          22,50
# 2         19,10          13,60
# 3         13,50           4,70
# 4         16,00           3,90

# %% [markdown]
# **Tip:** Si no usas `print()` la tabla se vera mejor.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Cargaste correctamente las librerías y ambos datasets **traffic** y **eco**, y además mostraste una vista rápida con `.head()`, lo que ayuda a validar que la lectura quedó bien. La estructura inicial queda clara para arrancar el proceso de limpieza sin perder contexto.
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 2: Explorar, limpiar y preparar los datos
#
# Antes de combinar los datasets, inspecciona su estructura, tipos de datos, columnas y valores faltantes.
# Anota las columnas que necesiten limpieza y luego estandariza los nombres de columnas.
#
# ### 2.1 Explorar la estructura y tipos de datos
#
# **🎯Objetivo:**
# Identificar columnas con tipos incorrectos, distribución y nulos, anotar las columnas que requieren conversión.
#
# **Instrucciones:**
#
# - Usa `.info()` para conocer la estructura de ambos DataFrames.
# - Muestra los primeros 3 renglones de cada DF.
# - Identifica si los detalles de cada DF estan bien o si requieren correcciones y escribe tus conclusiones en el bloque Markdown.
#   - ¿Hay columnas que requieren conversión?¿ Cuáles son? ¿Que tipo de dato ienen y cuál deberían de tener?
#   - ¿Hay datos ausentes en alguna columna?

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004464 entries, 0 to 1004463
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Country                         1004464 non-null  object
#  1   City                            1004464 non-null  object
#  2   UpdateTimeUTC                   1004464 non-null  object
#  3   JamsDelay                       1004464 non-null  float64
#  4   TrafficIndexLive                1004464 non-null  float64
#  5   JamsLengthInKms                 1004464 non-null  float64
#  6   JamsCount                       1004464 non-null  float64
#  7   TrafficIndexWeekAgo             1004464 non-null  float64
#  8   UpdateTimeUTCWeekAgo            1004464 non-null  object
#  9   TravelTimeLivePer10KmsMins      1004464 non-null  float64
#  10  TravelTimeHistoricPer10KmsMins  1004464 non-null  float64
#  11  MinsDelay                       1004464 non-null  float64
# dtypes: float64(8), object(4)
# memory usage: 92.0+ MB

# %% [markdown]
# En la estructura del DF traffic, se observa que:
# - Las columnas `UpdateTimeUTC` y `UpdateTimeUTC` son de tipo object (texto) cuando deberían ser datetime
# - Todas las métricas numéricas (JamsDelay, TrafficIndexLive, etc.) están correctamente como float64
# - No hay valores nulos en ninguna columna (1,004,464 registros completos)
# - El dataset es muy grande con más de 1 millón de registros

# %%
eco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             30 non-null     int64
#  1   City             30 non-null     object
#  2   Country          30 non-null     object
#  3   City GDP/capita  30 non-null     object
#  4   Unemployment %   30 non-null     object
#  5   PM2.5 (μg/m³)    30 non-null     object
#  6   Population (M)   30 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.8+ KB

# %% [markdown]
# En la estructura del DF eco, se observa que:
# - Las columnas `City GDP/capita`, `Unemployment %`, PM2.5 (μg/m³)`, `Population (M)` son de tipo object (texto) cuando deberian ser float64
# - Las columnas City y Country son de tipo object, estan correctas
# - No hay valores nulos (30 registros completos)...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Usaste `.info()` en **traffic** y **eco**, lo cual es lo adecuado para revisar tipos y nulos. Sin embargo, las observaciones quedaron como plantilla (“…”) y falta concretar qué columnas venían con tipos problemáticos para que la revisión quede completa.
#
# </div>

# %% [markdown]
# ### 2.2 Renombrar columnas
#
# **🎯Objetivo:**
# Estandarizar los nombres de columnas para evitar errores y facilitar la unión de los datasets.
#
# **Instrucciones:**
#
# - Cambia los nombres de las columnas para que tengan el formato `snake_case`.
#     - `Country` → `country`
#     - `UpdateTimeUTC` → `update_time_utc`
# - Verifica que los cambios se hayan aplicado correctamente usando `.columns`.

# %%
traffic=traffic.rename(columns={'Country': 'country', 'UpdateTimeUTC':'update_time_utc','City':'city','JamsDelay':'jams_delay','TrafficIndexLive':'traffic_index_live','JamsLengthInKms':'jams_length_inkms','JamsCount':'jams_count','TrafficIndexWeekAgo':'traffic_index_week_ago','UpdateTimeUTCWeekAgo':'update_time_utc_week_ago','TravelTimeLivePer10KmsMins':'travel_time_live_per10_kms_mins','TravelTimeHistoricPer10KmsMins':'travel_time_historic_per10_kms_mins','MinsDelay':'mins_delay'})# Estandarizar los nombres de las columnas de traffic
#tu código aquí

# verificar cambios
traffic.columns
# Out:
# Index(['country', 'city', 'update_time_utc', 'jams_delay',
#        'traffic_index_live', 'jams_length_inkms', 'jams_count',
#        'traffic_index_week_ago', 'update_time_utc_week_ago',
#        'travel_time_live_per10_kms_mins',
#        'travel_time_historic_per10_kms_mins', 'mins_delay'],
#       dtype='object')

# %%
# Estandarizar los nombres de las columnas de eco
eco=eco.rename(columns={'Year':'year','City':'city','Country':'country','City GDP/capita':'city_gdp_capita','Unemployment %':'unemployment_pct', 'PM2.5 (μg/m³)':'pm25_ugm3','Population (M)':'population_m'}) #tu código aquí

# verificar cambios
eco.columns
# Out:
# Index(['year', 'city', 'country', 'city_gdp_capita', 'unemployment_pct',
#        'pm25_ugm3', 'population_m'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# La estandarización en **traffic** quedó bien alineada a `snake_case`, pero en **eco** quedaron nombres inconsistentes (*unemployment_%*, *pm2.5_(μg/m³)*, *population_(m)*) que luego no coinciden con los nombres que se usan más adelante. Esa inconsistencia rompe el flujo y complica la unión y el análisis.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente Leidy, has renombrado correctamente las columnas, esto garantizará un flujo adecuado para el análisis
# </div>

# %% [markdown]
# ### 2.3 Corregir formatos numéricos y de fecha
#
# **🎯Objetivo:**
# Asegurar que las columnas de fechas y valores numéricos estén en formatos correctos para permitir análisis, cálculos y comparaciones precisas.
#
# **Instrucciones:**
#
# - Convierte las columnas de fecha de `traffic` a formato `datetime`. Haz el cambio a prueba de errores.
# - En el dataset `eco`, limpia los valores numéricos:
#     - En `city_gdp_capita`: elimina separadores de miles (`.`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `unemployment_pct`: elimina el símbolo de porcentaje (`%`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `population_m`: reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
# - Finalmente, crea una nueva columna llamada `population` multiplicando `population_m` por 1,000,000 para obtener la población total.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# para eliminar símbolos, puedes reemplazarlos por un texto vacío.

# %%
# Convertir las columnas de traffic a tipo fecha con pd.to_datetime()
traffic['update_time_utc'] =pd.to_datetime(traffic['update_time_utc']) #tu código aquí
traffic['update_time_utc_week_ago'] = pd.to_datetime(traffic['update_time_utc_week_ago'],errors='coerce')#tu código aquí



# verificar el cambio
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004464 entries, 0 to 1004463
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   country                              1004464 non-null  object
#  1   city                                 1004464 non-null  object
#  2   update_time_utc                      1004464 non-null  datetime64[ns]
#  3   jams_delay                           1004464 non-null  float64
#  4   traffic_index_live                   1004464 non-null  float64
#  5   jams_length_inkms                    1004464 non-null  float64
#  6   jams_count                           1004464 non-null  float64
#  7   traffic_index_week_ago               1004464 non-null  float64
#  8   update_time_utc_week_ago             1004464 non-null  datetime64[ns]
#  9   travel_time_live_per10_kms_mins      1004464 non-null  float64
#  10  travel_time_historic_per10_kms_mins  1004464 non-null  float64
#  11  mins_delay                           1004464 non-null  float64
# dtypes: datetime64[ns](2), float64(8), object(2)
# memory usage: 92.0+ MB

# %%
# Limpia separadores y convierte columnas numéricas en eco
eco['city_gdp_capita'] = eco['city_gdp_capita'].astype(str).str.replace('.', '').str.replace(',', '.').astype(float)
eco['unemployment_pct'] = eco['unemployment_pct'].astype(str).str.replace('%','').str.replace(',','.').astype(float)
eco['population_m'] = eco['population_m'].astype(str).str.replace(',','.').astype(float)
eco['pm25_ugm3'] = eco['pm25_ugm3'].astype(str).str.replace(',', '.').astype(float)

# Calcula la población total en unidades absolutas (Multiplica * 1000000)
eco['population'] = eco['population_m'] *1000000

# verificar el cambio
eco.info()
eco.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              30 non-null     int64
#  1   city              30 non-null     object
#  2   country           30 non-null     object
#  3   city_gdp_capita   30 non-null     float64
#  4   unemployment_pct  30 non-null     float64
#  5   pm25_ugm3         30 non-null     float64
#  6   population_m      30 non-null     float64
#  7   population        30 non-null     float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 2.0+ KB
#    year            city    country  city_gdp_capita  unemployment_pct  \
# 0  2023    buenos-aires  Argentina       15782000.0               6.2
# 1  2023       sao-paulo     Brazil       14475000.0               9.1
# 2  2023  rio-de-janeiro     Brazil       13142000.0               9.8
#
#    pm25_ugm3  population_m    population
# 0       15.2    15300000.0  1.530000e+13
# 1       29.5    22500000.0  2.250000e+13
# 2       19.1    13600000.0  1.360000e+13

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Convertiste fechas y limpiaste valores numéricos clave, pero faltó dejar el proceso “a prueba de errores” en fechas y completar transformaciones críticas como crear *population* desde *population_m*, ya que la estás reemplazanedo. También queda pendiente alinear el nombre de *unemployment* para que sea consistente con el resto del notebook.
#
# Además, ten en cuenta que la columna *pm25* tiene información numérica, pero la dejaste como un `object` (texto), ya que su separador es una coma `(,)`. Debes asegurarte que todas tus columnas tengan el tipo adecuado, para evitar problemas o errores en el análisis
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Perfecto, has ajustado correctamente el formato y tipo de datos
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 3: Extraer año y filtrar
#
# Extraer el año permite filtrar la información y trabajar solo con el período más reciente y relevante.
#
# ### 3.1 Extraer columna año y filtrar 2024
#
# **🎯Objetivo**
# Identificar el año de cada registro y mantener solo los registros del 2024.
#
# **Intrucciones**
#
# - Como el DataFrame `traffic` no tiene una columna de año, utiliza el atributo `.dt.year` sobre su columna de fecha para crear una nueva columna llamada `year`.
# - Filtra las filas donde el año sea **2024**.
# - Utiliza `.copy()` para crear dos nuevos DataFrames (`traffic_2024` y `eco_2024`) para evitar modificar el dataset original.

# %%
# Extraer el año de las fechas en update_time_utc
# traffic['year'] = 
traffic['update_time_utc'] =pd.to_datetime(traffic['update_time_utc'])
traffic['year'] = traffic['update_time_utc'].dt.year

# Verificar cambio
traffic.head()
# Out:
#   country       city         update_time_utc  jams_delay  traffic_index_live  \
# 0     ARE  abu-dhabi 2025-01-13 04:01:30.001       650.7                36.0
# 1     ARE  abu-dhabi 2025-01-13 03:46:00.000       540.4                30.0
# 2     ARE  abu-dhabi 2025-01-13 02:46:30.000        71.8                 7.0
# 3     ARE  abu-dhabi 2025-01-13 01:46:30.001         8.2                 2.0
# 4     ARE  abu-dhabi 2025-01-13 00:01:30.000         1.1                 1.0
#
#    jams_length_inkms  jams_count  traffic_index_week_ago  \
# 0              109.1       162.0                    30.0
# 1              101.4       136.0                    27.0
# 2               18.9        23.0                     6.0
# 3                4.1         2.0                     2.0
# 4                0.2         1.0                     1.0
#
#   update_time_utc_week_ago  travel_time_live_per10_kms_mins  \
# 0  2025-01-06 04:01:30.000                        11.614767
# 1  2025-01-06 03:46:30.001                        11.003180
# 2  2025-01-06 02:46:30.000                         8.196278
# 3  2025-01-06 01:46:30.000                         7.723808
# 4  2025-01-06 00:01:30.000                         8.336363
#
#    travel_time_historic_per10_kms_mins  mins_delay  year
# 0                            10.265330    1.349437  2025
# 1                            10.031544    0.971635  2025
# 2                             8.196510   -0.000232  2025
# 3                             7.899046   -0.175238  2025
# 4                             8.604379   -0.268016  2025

# %%
# Filtra los registros del año 2024
traffic_2024 = traffic[traffic['update_time_utc'].dt.year == 2024].copy()
# traffic_2024 = traffic[...].copy()
eco_2024 = eco[eco['year'] == 2024].copy()
# eco_2024 = ...

# Revisar dataframes nuevos
display(traffic_2024.head())
display(eco_2024.head())
# Out:
#     country       city         update_time_utc  jams_delay  \
# 302     ARE  abu-dhabi 2024-12-31 23:01:30.000        12.9
# 303     ARE  abu-dhabi 2024-12-31 22:01:30.000       136.0
# 304     ARE  abu-dhabi 2024-12-31 21:16:30.000       455.2
# 305     ARE  abu-dhabi 2024-12-31 20:01:00.001       399.4
# 306     ARE  abu-dhabi 2024-12-31 19:46:00.000       366.4
#
#      traffic_index_live  jams_length_inkms  jams_count  \
# 302                 5.0                2.5         5.0
# 303                21.0               20.6        32.0
# 304                31.0               40.4        72.0
# 305                27.0               38.0        75.0
# 306                28.0               39.8        82.0
#
#      traffic_index_week_ago update_time_utc_week_ago  \
# 302                     2.0  2024-12-24 23:01:30.001
# 303                     3.0  2024-12-24 22:01:30.000
# 304                     4.0  2024-12-24 21:01:30.000
# 305                     6.0  2024-12-24 20:01:30.001
# 306                     9.0  2024-12-24 19:01:00.000
#
#      travel_time_live_per10_kms_mins  travel_time_historic_per10_kms_mins  \
# 302                         8.560399                             8.519634
# 303                        10.355732                             9.049445
# 304                        11.456878                             9.305174
# 305                        11.670062                             9.952811
# 306                        11.686322                            10.008469
#
#      mins_delay  year
# 302    0.040765  2024
# 303    1.306286  2024
# 304    2.151704  2024
# 305    1.717252  2024
# 306    1.677853  2024
#     year            city    country  city_gdp_capita  unemployment_pct  \
# 15  2024    buenos-aires  Argentina       18117000.0               7.2
# 16  2024       sao-paulo     Brazil       14703000.0               8.5
# 17  2024  rio-de-janeiro     Brazil       13349000.0               9.2
# 18  2024        brasilia     Brazil       16251000.0               7.8
# 19  2024        salvador     Brazil        8899000.0              12.4
#
#     pm25_ugm3  population_m    population
# 15       14.5    15400000.0  1.540000e+13
# 16       28.0    22600000.0  2.260000e+13
# 17       18.4    13700000.0  1.370000e+13
# 18       12.8     4800000.0  4.800000e+12
# 19       15.2     3900000.0  3.900000e+12

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# La extracción del año se hizo desde *update_time_utc_week_ago* y el filtrado 2024 también quedó amarrado a esa columna, lo que puede cambiar el período real que estás analizando. Para responder la consigna, el año debería salir de *update_time_utc* (la medición principal) y luego validar que los años filtrados sean únicamente 2024.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Perfecto Leidy
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 4: Analizar y resumir datos de movilidad
#
# Como el dataset de tráfico contiene **múltiples registros por ciudad**. En esta parte, calcularás los promedios anuales por ciudad para simplificar el análisis y obtener una visión más clara de las tendencias generales.
#
# ### 4.1 Calcular promedios de tráfico por ciudad
#
# **🎯Objetivo:**
# Obtener una vista consolidada del tráfico promedio por ciudad y año, para analizar patrones generales sin depender de datos diarios.
#
# **Instrucciones**
#
# - Agrupa los datos por `city`, `country` y `year`.
# - Calcula el promedio **solo de las métricas de tráfico más relevantes**: como `jams_delay`, `traffic_index_live`, `jams_length_kms`, `jams_count`, `mins_delay`, y tiempos de viaje (`travel_time_live_per_10kms_mins` y `travel_time_hist_per_10kms_mins`).
# - Guarda el resultado como `traffic_city_year_2024`, mantén las columnas como variables (no índices).

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Usa ".agg()" para aplicar funciones de promedio. Al final, reinicia el índice para mantener las columnas de la agrupación como variables (no índices).

# %%
# Calcular los  promedios de trafico por ciudad, país y año
traffic_city_year_2024 =  traffic_2024.groupby(['city','country','year']).agg({'jams_delay':'mean','traffic_index_live':'mean','jams_length_inkms':'mean','jams_count':'mean','mins_delay':'mean','travel_time_live_per10_kms_mins':'mean','travel_time_historic_per10_kms_mins':'mean'}).reset_index()# tu código aqui

# Mostrar resultado
traffic_city_year_2024.head()
# Out:
#         city country  year  jams_delay  traffic_index_live  jams_length_inkms  \
# 0   a-coruna     ESP  2024   17.935187           15.259774           2.198002
# 1     aachen     DEU  2024   26.732141           20.960314           3.892586
# 2     aarhus     DNK  2024   21.200616           16.575891           2.736736
# 3  abu-dhabi     ARE  2024  171.157315           13.902028          24.507380
# 4      adana     TUR  2024   83.864761           22.541040          11.827331
#
#    jams_count  mins_delay  travel_time_live_per10_kms_mins  \
# 0    4.934405    0.774172                        16.267977
# 1    6.601832    0.792968                        13.397861
# 2    6.109987    0.495276                        15.219292
# 3   47.268019    0.139764                         9.829092
# 4   23.754620    1.129749                        15.879694
#
#    travel_time_historic_per10_kms_mins
# 0                            15.493804
# 1                            12.604894
# 2                            14.724016
# 3                             9.689328
# 4                            14.749945

# %% [markdown]
# ### 🧠 **Momento de reflexión**
#
# ¡Excelente trabajo hasta aquí!
#
# Ahora que ya tienes los promedios anuales por ciudad, es momento de **observarlos** con atención.
#
# Piensa:
#
# - ¿Cuál crees que tiene el mayor tiempo promedio de tráfico?
# - ¿Será una ciudad de **Europa**, de **Latinoamérica** o de **otra región** del mundo?
#
# Para descubrirlo, ejecuta esta línea de código:
#
# `traffic_city_year_2024.sort_values(["jams_delay"], ascending=False)`
#
#
# 🔍 Observa qué ciudad aparece en los primeros lugares.
#
# ¿Te sorprenden los resultados? , ¿Coinciden con lo que imaginabas?

# %%
traffic_city_year_2024.sort_values(["jams_delay"], ascending=False)# tu código aquí
# Out:
#             city country  year   jams_delay  traffic_index_live  \
# 221  mexico-city     MEX  2024  2833.057892           34.218190
# 352        tokyo     JPN  2024  2152.574357           36.805059
# 246     new-york     USA  2024  2133.400000           28.210388
# 200       london     GBR  2024  2050.703662           29.230166
# 211       manila     PHL  2024  1741.493381           66.129402
# ..           ...     ...   ...          ...                 ...
# 111      dunedin     NZL  2024     4.651175           15.430809
# 363      uppsala     SWE  2024     4.194486           13.939168
# 123     fujairah     ARE  2024     4.025959           10.907719
# 12        almere     NLD  2024     3.633523            6.290478
# 117      el-paso     USA  2024     0.299024            2.340435
#
#      jams_length_inkms  jams_count  mins_delay  \
# 221         389.239265  594.969392    1.855542
# 352         373.069734  518.809420    0.698152
# 246         398.227892  544.474902    1.396351
# 200         287.632868  471.795554    1.325160
# 211         246.858082  341.881205    2.469894
# ..                 ...         ...         ...
# 111           0.712315    1.591384    0.633294
# 363           0.656368    1.349672    0.501802
# 123           0.731910    1.373006    0.194951
# 12            0.506362    1.064063   -0.017544
# 117           0.031114    0.078118   -0.250676
#
#      travel_time_live_per10_kms_mins  travel_time_historic_per10_kms_mins
# 221                        21.809092                            19.953550
# 352                        22.443778                            21.745626
# 246                        18.505043                            17.108691
# 200                        17.714139                            16.388979
# 211                        27.134629                            24.664734
# ..                               ...                                  ...
# 111                        16.226009                            15.592715
# 363                        15.746717                            15.244916
# 123                        11.662590                            11.467639
# 12                          9.467150                             9.484694
# 117                        10.690269                            10.940945
#
# [387 rows x 10 columns]

# %% [markdown]
# La ciudad con el mayor tiempo promedio de tráfico es Mexico city

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# La agregación por *city–country–year* y el cálculo de promedios de métricas de tráfico están bien planteados. Aun así, en la validación terminaste mostrando **traffic** en vez de revisar el resultado agregado (**traffic_city_year_2024**) con `.head()` para confirmar que la tabla final quedó con una fila por ciudad-año.
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 5: Unir movilidad y economía
#
# Combinar datasets te permite analizar cómo se relacionan los indicadores económicos con los de movilidad.
#
# ### 5.1 Unir tráfico (tabla principal) con indicadores económicos
#
# **🎯Objetivo:**
# Combinar la información de tráfico y economía en un solo DataFrame para analizar cómo las condiciones económicas se relacionan con la movilidad urbana.
#
# **Instrucciones**
# - Selecciona solo las **columnas relevantes** de cada dataset (por ejemplo, variables clave de tráfico y de economía).
# - Usa `.copy()` al crear subconjuntos para evitar modificar el dataset original.
# - Une ambos DataFrames y define como **claves de unión** a `city` y `year`.
# - Mantén solo las ciudades y años presentes en ambos datasets.
# - Guarda el resultado en una nueva variable llamada `merged` y muestra las primeras 5 filas.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Aplica una unión de tipo "inner" para mantener las ciudades y años presentes en ambos datasets.

# %%
# Seleccionar columnas clave de tráfico y economía
left_cols = ['city','country','year','jams_delay','traffic_index_live',
             'jams_length_inkms','jams_count','mins_delay',
             'travel_time_live_per10_kms_mins','travel_time_historic_per10_kms_mins']

right_cols = ['city','year','city_gdp_capita','unemployment_pct','pm25_ugm3','population_m']

# Usar .copy() para crear los dos nuevos datasets reducidos
traffic_2024_small = traffic_city_year_2024[left_cols].copy()
eco_2024_small = eco_2024[right_cols].copy()

# Unir datasets
merged_inner= pd.merge(traffic_2024_small,eco_2024_small,on=['city','year'],how='inner')
merged_inner.head(5)
# Mostrar las primeras 5 filas

# tu código aquí
# Out:
#              city country  year   jams_delay  traffic_index_live  \
# 0  belo-horizonte     BRA  2024   263.047879           19.428946
# 1          bogota     COL  2024  1141.552364           37.614273
# 2        brasilia     BRA  2024   101.576326           11.258220
# 3    buenos-aires     ARG  2024   571.089593           17.756012
# 4        curitiba     BRA  2024   183.469274           14.954545
#
#    jams_length_inkms  jams_count  mins_delay  travel_time_live_per10_kms_mins  \
# 0          44.038129   68.805422    0.487228                        18.304538
# 1         140.893564  230.566550    1.699628                        24.992185
# 2          18.337133   27.280140    0.193442                        13.338658
# 3         100.287844  137.359860    0.416566                        17.907916
# 4          30.050044   46.898164    0.139965                        17.258700
#
#    travel_time_historic_per10_kms_mins  city_gdp_capita  unemployment_pct  \
# 0                            17.817311       11124000.0               9.5
# 1                            23.292557       11442000.0              10.0
# 2                            13.145216       16251000.0               7.8
# 3                            17.491349       18117000.0               7.2
# 4                            17.118736       12381000.0               8.2
#
#    pm25_ugm3  population_m
# 0       16.8     6100000.0
# 1       17.6    11300000.0
# 2       12.8     4800000.0
# 3       14.5    15400000.0
# 4       13.5     3700000.0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# El `merge` se ejecutó, pero la selección de columnas quedó definida y no se aplicó (*right_cols* y *left_cols*, y además hay un problema de consistencia en claves y nombres de columnas (por ejemplo, *unemployment_pct*, *pm25*, *population* no existen con esos nombres en **eco_2024** tras tu renombrado). También queda inconsistente usar **merged_inner** y luego exportar **merged**, que no se creó.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Excelente trabajo Leidy
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 6: Visualización y análisis de relaciones
#
# Ahora que tienes un dataset limpio y unificado, es momento de **visualizar patrones**.
# Los gráficos te ayudarán a entender cómo se relacionan las variables económicas con las de movilidad urbana.
#
# ### 6.1 Visualizar relaciones entre economía y tráfico
#
# **🎯Objetivo:**
# Analizar visualmente la distribución y la relación entre indicadores de tráfico y economía en 2024, para identificar posibles patrones o tendencias generales entre ambas variables.
#
# **Instrucciones**
# - Usa las librerías `seaborn` y `matplotlib.pyplot` para generar los gráficos.
# - Visualiza la distribución del **tráfico** (`jams_delay`) mediante:
#     - **Boxplot** → para observar la media, mediana y detectar valores atípicos.
# - Visualiza la distribución de la **economía** (`city_gdp_capita`) mediante:
#     - **Histograma** → para analizar la forma de la distribución y el valor promedio del PIB per cápita.
# - Finalmente, **compara ambas variables**, para observar si existe alguna relación entre ellas, haciendo un solo gráfico de barras donde aparezcan ambos indicadores.
# - Recuerda agregar título y etiquetas a los ejes de tus gráficos.
# - Observa y comenta los patrones, valores extremos o posibles relaciones que identifiques.

# %% [markdown]
# **Tip:** Dentro de los parentesis del boxplot, agrega `showmeans=True` para ver la media en el gráfico.

# %%
mean_value = traffic_2024_small['jams_delay'].mean()
median_value = traffic_2024_small['jams_delay'].median()# Crear boxplot para observar el comportamiento de los minutos de congestion JamsDelay
plt.figure(figsize=(10, 6))
plt.boxplot(traffic_2024_small['jams_delay'].dropna(),showmeans=True)
plt.title(f'Boxplot de JamsDelay (2024)\nMedia: {mean_value:.2f} | Mediana: {median_value:.2f}')
plt.ylabel('Jams Delay (minutos)')
plt.xlabel('Distribución del Tráfico')
plt.grid(True, alpha=0.3)

# crea tu gráfico

# obtener promedio para mostrarlo en título
mean_value = merged_inner['jams_delay'].mean()
plt.title(f'Boxplot de JamsDelay (2024)\nPromedio: {mean_value:.2f}')
plt.show()

# %%
eco_2024_small ['city_gdp_capita'].hist(bins=10)
plt.title('Distribución del PIB per Cápita')
plt.xlabel('PIB per Cápita')
plt.ylabel('frecuencia')

plt.show()
# Crear histograma para ver la distribución de la economía (city_gdp_capita)

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))

# PRIMER EJE (izquierdo) - Jams Delay
cities = merged_inner['city']
bars = ax1.bar(cities, merged_inner['jams_delay'], 
               alpha=0.7, color='orange', label='Jams Delay')
ax1.set_xlabel('Ciudad')
ax1.set_ylabel('Jams Delay (minutos)', color='orange')
ax1.tick_params(axis='y', labelcolor='orange')
ax1.tick_params(axis='x', rotation=90)

# SEGUNDO EJE (derecho) - PIB per cápita
ax2 = ax1.twinx()  # ¡Línea clave!
bars = ax2.plot(cities, merged_inner['city_gdp_capita'], 
                color='blue', marker='o', linewidth=2, 
                markersize=8, label='PIB per cápita')
ax2.set_ylabel('PIB per cápita', color='blue')
ax2.tick_params(axis='y', labelcolor='blue')

# Título y leyenda
plt.title('Retrasos por Congestión VS PIB per Cápita por ciudad')

# Leyenda combinada
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')


plt.show()

# %% [markdown]
# **Tip:** Antes del `plt.show()` agrega el código `plt.xticks(rotation=90)` para rotar las etiquetas del eje X en 90 grados.

# %% [markdown]
# ### 🧠 **Reflexiona**
# Excelente trabajo llegando a esta etapa del análisis. Antes de avanzar, revisa tus gráficos, tómate un momento para pensar:
#
# * ¿Las ciudades con mayor PIB per cápita también presentan más congestión?
#
# * ¿O sucede lo contrario, o no existe una relación clara?

# %% [markdown]
# Las ciudades con mayor PIB per cápita también presentan más congestión? No en realidad por ejemplo Montevideo la ciudad con el punto más alto del PIB per cápita,vemos que sus barras de congestión son de las más bajas del gráfico. Esto rompe la idea de que "más riqueza = más tráfico".
#
# . Sucede lo contrario? Tampoco. No podemos decir que a menor PIB haya más tráfico. Por ejemplo, Santiago tiene el PIB más bajo de la muestra, pero su congestión es moderada-alta (mayor que la de Buenos Aires o Curitiba, que tienen más PIB).
# No existe una correlación lineal positiva entre la riqueza de la ciudad (PIB per cápita) y el nivel de tráfico (Jams Delay).
#
# . Existe una relacion clara?
# No existe una correlación  clara entre estas dos variables
#
# Caso Montevideo: Tiene el PIB per cápita más alto de la muestra, pero sus niveles de retraso por congestión son de los más bajos. Esto sugiere una infraestructura eficiente o una densidad poblacional/vehicular controlada.
#
# Caso Mexico-City: Es el "outlier" (valor atípico) más diferenciado. Tiene un PIB per cápita alto (el segundo más alto), pero sus niveles de congestión son desproporcionadamente superiores al resto de las ciudades.
#
# Brasilia: Tienen niveles de PIB similares o superiores a Sao Paulo, pero una fracción mínima de su tráfico.
#
# Lo que este gráfico nos sugiere es que la congestión depende de otras variables que no estan determinadas aqui podrían ser: *diseño urbano
# *densidad poblacional
# *Calidad del transporte público
# *Estado de las vias

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteración)</b> <a class="tocSkip"></a>
#
#
# En este paso hay inconsistencias que afectan ejecución e interpretación:
#
# * En el primer gráfico usas dos veces `plt.show`, lo que genera un gráfico vacío. Debes hacer la configuración del gráfico y solo al final usar `plt.show`
# * Estas reimportando innecesariamente `import matplotlib.pyplot as plt`, ya lo habias hecho de manera correcta al inicio del notebook
# * Los datos no son los esperados por el problema con **merged_inner** que te mencioné más arriba, cuando ajustes esto, podrás obtener los datos correctos.
# * Como recomendación para la última gráfica, al mezclar variables con escalas tan distintas el mensaje puede volverse confuso, podrías usar gráficos separados o normalizar los valores. Otra opción sería configurar dos ejes Y distintos, lo cual permita presentar la información de manera más clara. Te comparto una página donde explican como hacer esta configuración: [Enlace](https://www.analyticslane.com/2022/08/04/uso-de-multiples-ejes-en-matplotlib/). La idea es obtener algo como esto:
#
# <img src="https://www.edureka.co/community/?qa=blob&qa_blobid=5104085296578093682" width="300">
#
# * Recueda incluir tu análisis e interpretación para que la información no se quede solo como datos
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Gran trabajo has ajustado correctamente los gráfico, ahora su análisis es más fácil de implementar
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 7: Exportar y documentar resultados
#
# En esta etapa final consolidarás todo tu trabajo: guardarás el dataset limpio y crearás un resumen que documente los resultados del proyecto.
#
# ### 7.1 Guardar dataset final
#
# **🎯Objetivo:**
# Generar un CSV limpio, reproducible y con columnas relevantes para análisis posterior.
#
# **Instrucciones**
#
# - Exporta el DataFrame `merged` con el nombre: `ladb_mobility_economy_2024_clean.csv`
# - Usa `index=False` para no incluir el índice.

# %%
merged = merged_inner.copy()
merged.to_csv("ladb_mobility_economy_2024_clean.csv", index=False)

# %% [markdown]
# Para poder ver o descargar el archivo generado:
# En el menú lateral que esta a la izquierda, ve hasta la parte de abajo, a la sección de **Exportar dataset** para más información.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# La exportación apunta al archivo correcto, pero se intenta guardar **merged**, que no está definido (el DataFrame que sí existe es **merged_inner**). También faltó una validación mínima del archivo exportado (por ejemplo, confirmar tamaño o que el CSV no quede vacío) para cerrar la entrega con seguridad.
#
# </div>

# %% [markdown]
# ---
#
# ## ✅ Entregables
#
# 1. **Notebook `.ipynb`** con todas las celdas (código + comentarios).
# 2. **CSV final**: `ladb_mobility_economy_2024_clean.csv`.
# 3. **Resumen ejecutivo breve** en Markdown (3–5 párrafos).

# %% [markdown]
# ---
#
# # 🧾 Resumen ejecutivo (plantilla)
#
# > Completa este resumen al finalizar el análisis. Mantén 3–5 párrafos cortos, claros y accionables.
#
# **Contexto & objetivo:**
# - Responde la pregunta central del análisis: ¿qué relación existe entre la movilidad urbana (congestión, tiempos de viaje) y la productividad económica (PIB per cápita)?
# - Explica brevemente las variables clave utilizadas y su relevancia para la toma de decisiones.
#
# **Cobertura de datos:**
# - Especifica los años analizados, número de ciudades y países incluidos.
#
# **Metodología (alto nivel):**
# - Describe los procesos principales: limpieza de datos (formatos, estandarización de columnas).
# - Explica la agregación por ciudad–año y el uso de una unión INNER para integrar tráfico y economía.
# - Menciona las validaciones visuales empleadas (distribuciones, outliers, tendencias generales).
#
# **Hallazgos iniciales:**
# - Resume los patrones más importantes entre índices de tráfico y PIB per cápita.
# - Destaca anomalías u outliers que podrían requerir revisión adicional o un análisis más profundo.
#
# **Recomendaciones**
# Aterriza los hallazgos en acciones: ciudades prioritarias, necesidad de validar fuentes, requerimiento de análisis adicionales, o propuestas de inversión.
#
# - ¿Qué ciudad : Bogotá, Lima o Buenos Aires o alguna otra en particular, muestra la mayor correlación significativa entre altos niveles de congestión vehicular y bajos indicadores de productividad económica, sugiriendo ser una ciudad prioritaria para inversión en infraestructura de transporte?

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Tu resumen ejecutivo no está desarrollado y se mantiene en formato guía, así que todavía no se comunican hallazgos, implicaciones ni recomendaciones. Para cerrar esta parte, hace falta redactar 3–5 párrafos conectando congestión/tiempos de viaje con PIB per cápita/desempleo y mencionando qué ciudades se ven más prioritarias según tus gráficos.
#
# </div>

# %% [markdown]
# Qué relación existe entre la movilidad urbana y la productividad económica?
# Tras el análisis, se observa que no existe una correlación directa entre el PIB per cápita y la congestión. Esto sugiere que la riqueza de una ciudad no garantiza una movilidad eficiente, ni la pobreza es la causa única del tráfico. La relación está mediada por la calidad de la infraestructura y la planificación urbana, más que por el flujo de capital per cápita.
#
# Variables clave:
#
# Jams Delay (minutos): Métrica operativa de ineficiencia. Impacta directamente en los costos logísticos y la calidad de vida.
#
# PIB per cápita: Indicador de productividad económica. Crucial para entender si el crecimiento económico está siendo "asfixiado" por el tráfico.
#
# 2. Cobertura de Datos y Metodología
#
# Temporalidad: Datos correspondientes al año 2024.
#
# Alcance: 15 ciudades distribuidas en 7 países: Brasil (BRA), Colombia (COL), Argentina (ARG), Perú (PER), México (MEX), Uruguay (URY) y Chile (CHL).
#
# Metodología:
#
# Limpieza: Estandarización de nombres de ciudades, Cambiar los nombres de las columnas para que tengan el formato snake_case y cambio en tipo de datos de las columnas de acuerdo a necesidad
#
# Integración: Unión tipo INNER JOIN de bases de datos de tráfico y económicas por ciudad.
#
# Validación: Identificación de outliers y análisis de dispersión para confirmar tendencias.
#
# Hallazgos Iniciales
# Ausencia de Correlación Lineal: Los datos de 2024 demuestran que el PIB per cápita no es un predictor del tráfico.
#
# Referente de Eficiencia: Montevideo (URY) se posiciona como la ciudad líder en equilibrio, logrando el PIB más alto de la muestra con uno de los niveles de congestión más bajos.
#
# Puntos de Saturación: Mexico-City (MEX) y Sao Paulo (BRA) presentan una congestión que parece haber superado su capacidad de gestión, actuando como un "techo" para su crecimiento económico.
#
# Al comparar ciudades con desafíos similares de infraestructura:
#
# Bogotá (COL) destaca como la ciudad con la correlación más negativa. Presenta el segundo nivel de congestión más alto de toda la región (superado solo por México), pero con un PIB per cápita significativamente menor al de sus pares.
#
# Esto indica que en Bogotá el tráfico no es "consecuencia del éxito", sino una falla estructural que drena la productividad diaria. Junto con Lima (PER), representan los puntos con mayor urgencia de inversión en transporte masivo para liberar el potencial económico estancado

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (2da Iteración)</b> <a class=“tocSkip”></a>
#
# Logras construir una lectura clara al separar la idea de riqueza económica de la eficiencia en movilidad, mostrando que el problema va más por cómo se gestiona la ciudad que por cuánto produce. También conectas bien la congestión con efectos concretos sobre costos y bienestar, y utilizas comparaciones entre ciudades para darle más sentido al análisis, lo que ayuda a entender distintos escenarios dentro de la región.
#
# Sin embargo, en algunos puntos asumes relaciones causales que no están del todo sustentadas solo con correlaciones, por ejemplo al afirmar que ciertos casos actúan como límite al crecimiento; ahí haría falta mayor evidencia o al menos matizar esa interpretación.
#
# Para fortalecer futuros trabajos, podrías complementar con variables adicionales (como inversión pública o uso del transporte) y explorar modelos más robustos que te permitan ir más allá de la observación descriptiva.
#
# </div>
